# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/FSH_data/blob/master/FSH_Tim_Testing_10_18_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ForestStandHeightPackage==0.1
# Out:
# Collecting ForestStandHeightPackage==0.1
#   Downloading https://files.pythonhosted.org/packages/7f/b9/d82af3f611782d58de324ffb995cc505920ba8eb1245d0687766627ebc4d/ForestStandHeightPackage-0.1-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 2.8MB/s
# Installing collected packages: ForestStandHeightPackage
# Successfully installed ForestStandHeightPackage-0.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/leiyangleon/FSH.git
# Out:
# Cloning into 'FSH'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 203 (delta 3), reused 0 (delta 0), pack-reused 193
# Receiving objects: 100% (203/203), 850.84 KiB | 1.13 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# !git clone https://github.com/MayerT1/FSH_data.git
# Out:
# fatal: destination path 'FSH_data' already exists and is not an empty directory.

# %% [markdown]
# # Testing zone for pulled and mounted github
# # %cd content/FSH/scripts

# %%
# !ls
# %cd FSH/
# !ls
# %cd scripts/
# Out:
# drive  FSH  sample_data
# /content/FSH
# LICENSE      README.md	test_example_ISCE
# preview.jpg  scripts	test_example_ROIPAC
# /content/FSH/scripts

# %%
pip install 'simplekml'

# %%
# !ls
# Out:
# arc_sinc.py			   intermediate_pairwise.py
# auto_mosaicking_new.py		   intermediate.py
# auto_tree_height_many.py	   intermediate_self.py
# auto_tree_height_single_ISCE.py    ls_deltaSC.py
# auto_tree_height_single_ROIPAC.py  mean_wo_nan.py
# cal_error_metric_pairwise.py	   __pycache__
# cal_error_metric.py		   read_geo_data.py
# cal_error_metric_self.py	   read_linkfile.py
# cal_KB_pairwise_new.py		   read_rsc_data.py
# cal_KB.py			   remove_corr_bias.py
# cal_KB_self_new.py		   remove_nonforest.py
# create_mosaic.py		   remove_outlier.py
# CROP_ISCE.py			   write_deltaSC.py
# CROP_ROIPAC.py			   write_diff_height_map.py
# extract_scatterplot_density.py	   write_file_type.py
# flag_scene_file.py		   write_mapfile_new.py
# forest_stand_height.py

# %% [markdown]
# # testing zone for the shared FSH Trainign folder
# # %cd content/My Drive/FSH Training/testing_example

# %%
# %cd/
# !ls
# %cd/content
# Out:
# /
# bin	 datalab  home	 lib64	opt   run   swift	      tmp    var
# boot	 dev	  lib	 media	proc  sbin  sys		      tools
# content  etc	  lib32  mnt	root  srv   tensorflow-2.0.0  usr
# /content

# %%
# !ls
# %cd drive
# !ls
# Out:
# 'My Drive'  'Shared drives'
# [Errno 2] No such file or directory: 'drive'
# /content/drive
# 'My Drive'  'Shared drives'

# %%
# %cd My Drive/FSH Training
# Out:
# /content/drive/My Drive/FSH Training

# %%
# !ls
# Out:
#  01_ISCEInputFiles			   'Mekong Data (Quyen)'
#  Agenda_SCO_FSH.gdoc			    Process_LiDAR.gdoc
# 'ALOS L1.1'				   'PublicationProgress Ideas.gdoc'
#  Appendix_C_Revisions			    ROI_PAC.gdoc
# 'Chapter 5_FirstDraft_28sept2018 (1).pdf'  'SAR-FSH_Concept&Agenda.gdoc'
#  FeedbackfromSCOpresentation.gdoc	    SAR-FSH_Tag-up.gdoc
#  ForestStandHeightTutorial.gdoc		    SARHandbook_numbers_b.gslides
#  FSHscripts				    SARHandbook_numbers_b.pptx
#  FSH_WorkshopMaterials			    Siqueira
#  ISCE.gdoc				    stripmapApp.xml
#  ISCE_Install_Test.ipynb		   'Tag-up Agenda.gdoc'
#  JupyterTransferNotes.gdoc		    test_example_ISCE.zip

# %%
# !unzip test_example_ISCE.zip
# Out:
# Archive:  test_example_ISCE.zip
#    creating: test_example_ISCE/
#    creating: test_example_ISCE/f890_o119/
#   inflating: test_example_ISCE/f890_o119/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/test_example_ISCE/
#    creating: __MACOSX/test_example_ISCE/f890_o119/
#   inflating: __MACOSX/test_example_ISCE/f890_o119/._.DS_Store
#    creating: test_example_ISCE/f890_o119/int_070710_071010/
#   inflating: test_example_ISCE/f890_o119/int_070710_071010/resampOnlyImage.amp.geo.xml
#    creating: __MACOSX/test_example_ISCE/f890_o119/int_070710_071010/
#   inflating: __MACOSX/test_example_ISCE/f890_o119/int_070710_071010/._resampOnlyImage.amp.geo.xml
#   inflating: test_example_ISCE/f890_o119/int_070710_071010/.DS_Store
#   inflating: __MACOSX/test_example_ISCE/f890_o119/int_070710_071010/._.DS_Store
#   inflating: test_example_ISCE/f890_o119/int_070710_071010/topophase.cor.geo.xml
#   inflating: __MACOSX/test_example_ISCE/f890_o119/int_070710_071010/._topophase.cor.geo.xml
#   inflating: test_example_ISCE/f890_o119/int_070710_071010/topophase.cor.geo
#   inflating: __MACOSX/test_example_ISCE/f890_o119/int_070710_071010/._topophase.cor.geo
#   inflating: test_example_ISCE/f890_o119/int_070710_071010/resampOnlyImage.amp.geo
#   inflating: __MACOSX/test_example_ISCE/f890_o119/int_070710_071010/._resampOnlyImage.amp.geo
#   inflating: test_example_ISCE/f890_o119/int_070710_071010/isce.log
#   inflating: __MACOSX/test_example_ISCE/f890_o119/int_070710_071010/._isce.log
#   inflating: __MACOSX/test_example_ISCE/f890_o119/._int_070710_071010
#   inflating: __MACOSX/test_example_ISCE/._f890_o119
#    creating: test_example_ISCE/f890_o120/
#   inflating: test_example_ISCE/f890_o120/.DS_Store
#    creating: __MACOSX/test_example_ISCE/f890_o120/
#   inflating: __MACOSX/test_example_ISCE/f890_o120/._.DS_Store
#    creating: test_example_ISCE/f890_o120/int_070727_070911/
#   inflating: test_example_ISCE/f890_o120/int_070727_070911/resampOnlyImage.amp.geo.xml
#    creating: __MACOSX/test_example_ISCE/f890_o120/int_070727_070911/
#   inflating: __MACOSX/test_example_ISCE/f890_o120/int_070727_070911/._resampOnlyImage.amp.geo.xml
#   inflating: test_example_ISCE/f890_o120/int_070727_070911/.DS_Store
#   inflating: __MACOSX/test_example_ISCE/f890_o120/int_070727_070911/._.DS_Store
#   inflating: test_example_ISCE/f890_o120/int_070727_070911/topophase.cor.geo.xml
#   inflating: __MACOSX/test_example_ISCE/f890_o120/int_070727_070911/._topophase.cor.geo.xml
#   inflating: test_example_ISCE/f890_o120/int_070727_070911/topophase.cor.geo
#   inflating: __MACOSX/test_example_ISCE/f890_o120/int_070727_070911/._topophase.cor.geo
#   inflating: test_example_ISCE/f890_o120/int_070727_070911/resampOnlyImage.amp.geo
#   inflating: __MACOSX/test_example_ISCE/f890_o120/int_070727_070911/._resampOnlyImage.amp.geo
#   inflating: test_example_ISCE/f890_o120/int_070727_070911/isce.log
#   inflating: __MACOSX/test_example_ISCE/f890_o120/int_070727_070911/._isce.log
#   inflating: __MACOSX/test_example_ISCE/f890_o120/._int_070727_070911
#   inflating: __MACOSX/test_example_ISCE/._f890_o120
#    creating: test_example_ISCE/f890_o118/
#   inflating: test_example_ISCE/f890_o118/.DS_Store
#    creating: __MACOSX/test_example_ISCE/f890_o118/
#   inflating: __MACOSX/test_example_ISCE/f890_o118/._.DS_Store
#    creating: test_example_ISCE/f890_o118/int_070808_070923/
#   inflating: test_example_ISCE/f890_o118/int_070808_070923/resampOnlyImage.amp.geo.xml
#    creating: __MACOSX/test_example_ISCE/f890_o118/int_070808_070923/
#   inflating: __MACOSX/test_example_ISCE/f890_o118/int_070808_070923/._resampOnlyImage.amp.geo.xml
#   inflating: test_example_ISCE/f890_o118/int_070808_070923/.DS_Store
#   inflating: __MACOSX/test_example_ISCE/f890_o118/int_070808_070923/._.DS_Store
#   inflating: test_example_ISCE/f890_o118/int_070808_070923/topophase.cor.geo.xml
#   inflating: __MACOSX/test_example_ISCE/f890_o118/int_070808_070923/._topophase.cor.geo.xml
#   inflating: test_example_ISCE/f890_o118/int_070808_070923/topophase.cor.geo
#   inflating: __MACOSX/test_example_ISCE/f890_o118/int_070808_070923/._topophase.cor.geo
#   inflating: test_example_ISCE/f890_o118/int_070808_070923/resampOnlyImage.amp.geo
#   inflating: __MACOSX/test_example_ISCE/f890_o118/int_070808_070923/._resampOnlyImage.amp.geo
#   inflating: test_example_ISCE/f890_o118/int_070808_070923/isce.log
#   inflating: __MACOSX/test_example_ISCE/f890_o118/int_070808_070923/._isce.log
#   inflating: __MACOSX/test_example_ISCE/f890_o118/._int_070808_070923
#   inflating: __MACOSX/test_example_ISCE/._f890_o118
#   inflating: test_example_ISCE/.DS_Store
#   inflating: __MACOSX/test_example_ISCE/._.DS_Store
#   inflating: test_example_ISCE/ISCE.jpeg
#   inflating: __MACOSX/test_example_ISCE/._ISCE.jpeg
#   inflating: test_example_ISCE/Maine_NLCD2011_nonwildland.tif
#   inflating: __MACOSX/test_example_ISCE/._Maine_NLCD2011_nonwildland.tif
#   inflating: test_example_ISCE/flagfile.txt
#   inflating: __MACOSX/test_example_ISCE/._flagfile.txt
#   inflating: test_example_ISCE/linkfile.txt
#   inflating: __MACOSX/test_example_ISCE/._linkfile.txt
#   inflating: test_example_ISCE/Howland_LVIS_NaN.tif
#   inflating: __MACOSX/test_example_ISCE/._Howland_LVIS_NaN.tif
#   inflating: __MACOSX/._test_example_ISCE

# %%
# %cd test_example_ISCE/
# !ls
# Out:
# f890_o118  f890_o120	 Howland_LVIS_NaN.tif  linkfile.txt
# f890_o119  flagfile.txt  ISCE.jpeg	       Maine_NLCD2011_nonwildland.tif
# [Errno 2] No such file or directory: 'test_example_ISCE/'
# /content/drive/My Drive/FSH Training/test_example_ISCE
# f890_o118  f890_o120	 Howland_LVIS_NaN.tif  linkfile.txt
# f890_o119  flagfile.txt  ISCE.jpeg	       Maine_NLCD2011_nonwildland.tif

# %%
from IPython.display import Image
Image('ISCE.jpeg')

# %%
# !ls
# Out:
# f890_o118  f890_o120	 Howland_LVIS_NaN.tif  linkfile.txt
# f890_o119  flagfile.txt  ISCE.jpeg	       Maine_NLCD2011_nonwildland.tif

# %%
# %cd
# Out:
# /root

# %%
# %cd/content/FSH/scripts
# !ls
# Out:
# /content/FSH/scripts
# arc_sinc.py			   intermediate_pairwise.py
# auto_mosaicking_new.py		   intermediate.py
# auto_tree_height_many.py	   intermediate_self.py
# auto_tree_height_single_ISCE.py    ls_deltaSC.py
# auto_tree_height_single_ROIPAC.py  mean_wo_nan.py
# cal_error_metric_pairwise.py	   __pycache__
# cal_error_metric.py		   read_geo_data.py
# cal_error_metric_self.py	   read_linkfile.py
# cal_KB_pairwise_new.py		   read_rsc_data.py
# cal_KB.py			   remove_corr_bias.py
# cal_KB_self_new.py		   remove_nonforest.py
# create_mosaic.py		   remove_outlier.py
# CROP_ISCE.py			   write_deltaSC.py
# CROP_ROIPAC.py			   write_diff_height_map.py
# extract_scatterplot_density.py	   write_file_type.py
# flag_scene_file.py		   write_mapfile_new.py
# forest_stand_height.py

# %% [markdown]
# # II. Instructions and runtime estimates:
# The overall workflow for the forest stand height model is as follows:
#
# 1. Run ROI_PAC or ISCE (see parameter notes below)
# 2. Crop the ROI_PAC/ISCE output to eliminate the image margins (run standalone CROP_ROIPAC.py or CROP_ISCE.py)
# 3. Geocode the ROI_PAC/ISCE output
# 4. Run the Forest Stand Height python documents that are described in this document
# 5. Create the mosaic of the generated forest height maps for all of the scenes

# %%
# !python auto_tree_height_single_ROIPAC.py

# %%
# !python auto_tree_height_single_ISCE.py

# %% [markdown]
# # cmd block below needs to be updated to Py3 (failing due to prints)...most likely still and issue with packages after fixing the py2->Py3 **migration** **bold text**

# %% [markdown]
# forest_stand_height.py 3 2 2 5 "linkfile.txt" "flagfile.txt" "Howland_LVIS_NaN.tif" "Maine_NLCD2011_nonwildland.tif" /home/fsh/FSH/test_example_ROIPAC/test_example_ROIPAC/test_example_ROIPAC/ "gif json kml mat tif" --flag_diff=1 --flag_error=1 --flag_proc=0

# %%
# !python forest_stand_height.py 3 2 2 5 "linkfile.txt" "flagfile.txt" "Howland_LVIS_NaN.tif" "Maine_NLCD2011_nonwildland.tif" /root/content/My Drive/FSH_Training/test_example_ISCE/ "gif json kml mat tif" --flag_diff=1 --flag_error=1  --flag_proc=1
# Out:
# usage: forest_stand_height.py [-h] [--Nd_pairwise [ND_PAIRWISE]]
#                               [--Nd_self [ND_SELF]]
#                               [--N_pairwise [N_PAIRWISE]] [--N_self [N_SELF]]
#                               [--bin_size [BIN_SIZE]] [--flag_sparse [{0,1}]]
#                               [--flag_diff [{0,1}]] [--flag_error [{0,1}]]
#                               [--numLooks [NUMLOOKS]]
#                               [--noiselevel [NOISELEVEL]]
#                               [--flag_proc [{0,1}]] [--flag_grad [{0,1}]]
#                               scenes edges start_scene iterations linkfilename
#                               flagfile ref_file maskfile file_directory
#                               filetypes
# forest_stand_height.py: error: unrecognized arguments: gif json kml mat tif

# %%
# !python forest_stand_height.py
# Out:
# usage: forest_stand_height.py [-h] [--Nd_pairwise [ND_PAIRWISE]]
#                               [--Nd_self [ND_SELF]]
#                               [--N_pairwise [N_PAIRWISE]] [--N_self [N_SELF]]
#                               [--bin_size [BIN_SIZE]] [--flag_sparse [{0,1}]]
#                               [--flag_diff [{0,1}]] [--flag_error [{0,1}]]
#                               [--numLooks [NUMLOOKS]]
#                               [--noiselevel [NOISELEVEL]]
#                               [--flag_proc [{0,1}]] [--flag_grad [{0,1}]]
#                               scenes edges start_scene iterations linkfilename
#                               flagfile ref_file maskfile file_directory
#                               filetypes
# forest_stand_height.py: error: the following arguments are required: scenes, edges, start_scene, iterations, linkfilename, flagfile, ref_file, maskfile, file_directory, filetypes

# %% [markdown]
# # working Below....

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.16.5)

# %%
# forest_stand_height.py
# Tracy Whelen, Microwave Remote Sensing Lab, University of Massachusetts
# Yang Lei, Microwave Remote Sensing Lab, University of Massachusetts
# December 8, 2015
# Yang Lei, Jet Propulsion Labortary, California Institute of Technology
# May 18, 2017

# This script calls all the processing steps needed to take ROI_PAC/ISCE output and create a map of tree heights.

#!/usr/bin/python
from numpy import *
import auto_tree_height_many as athm
import read_linkfile as rlnk
import intermediate as inter
import intermediate_self as ins
import auto_mosaicking_new as amn
import write_deltaSC as wSC
import write_mapfile_new as wmn
import write_diff_height_map as wdm
import time
import pdb
import cal_error_metric as cem
import json
import argparse
import commands

# Define forest_stand_height function
# Input parameters are scenes, edges, start scene, iterations, link file, flag file, reference data file, file directory,
# list of all output tree height map file types, averaging numbers in lat and lon for "self" and "pairwise" fitting,
# averaging numbers in lat and lon for "self" and "pairwise" error calculation, bin_size for density calculation in scatter plot fitting,
# flag for sparse data cloud filtering, flag for exporting the diff_height maps, flag for exporting the json error metric files (for all flags 0 is no output, 1 is output)
# number of looks, thermal noise level, flag for processor selection, flag for temporal change gradient correction

def forest_stand_height(scenes, edges, start_scene, iterations, linkfilename, flagfile, ref_file, maskfile, file_directory, filetypes=['gif', 'json', 'kml', 'mat', 'tif'], Nd_pairwise=20, Nd_self=20, N_pairwise=20, N_self=20, bin_size=100, flag_sparse=0, flag_diff=0, flag_error=0, numLooks=20, noiselevel=0.0, flag_proc=0, flag_grad=0):
    
    print (time.strftime("%H:%M:%S"))
    
    # Set error warnings to ignore "invalid value" warnings caused by NaN values
    seterr(invalid='ignore')
    
    if flag_sparse == 1:
        Nd_self = 1

    commands.getoutput('mkdir '+file_directory+'output')
    
    # Extract the correlation map, kz, and corner coordinates for each scene
    athm.auto_tree_height_many(scenes, flagfile, file_directory, numLooks, noiselevel, flag_proc, flag_grad)

    if linkfilename == '-':
        # Run intermediate_self() (Central scene and LiDAR overlap)
        ins.intermediate_self(start_scene, flagfile, ref_file, maskfile, file_directory)
        edge_array = array([])
        print (time.strftime("%H:%M:%S"))
    else:
        # Read in the list of edges
        edge_array = rlnk.read_linkfile(edges, linkfilename, file_directory)
        # Calculate the overlap areas between the different scenes and the LiDAR (or other groundtruth)
        inter.intermediate(edges, start_scene, edge_array, maskfile, flagfile, ref_file, file_directory)

    # Mosaic the interferograms
    amn.auto_mosaicking_new(scenes, edges, start_scene, iterations, edge_array, file_directory, Nd_pairwise, Nd_self, bin_size, flag_sparse)
    
    # Store the delta S and C values for each scene
    wSC.write_deltaSC(scenes, iterations, flagfile, file_directory)
    
    # Create the tree height map
    wmn.write_mapfile_new(scenes, flagfile, maskfile, file_directory, filetypes)
    
    if flag_diff == 1:
        # Create the diff_height map
        wdm.write_diff_height_map(start_scene, ref_file, flagfile, maskfile, file_directory, filetypes)
    
    
    # Run cal_error_metric() when error metrics/scatter plots are needed
    if flag_error == 1:
        # Load the dp vector from the final iteration
        filename = "SC_%d_iter.json" % iterations
        ##        filename = "SC_%d_iter.json" % 6
        iter_file = open(file_directory + "output/" + filename)
        file_data = json.load(iter_file)
        iter_file.close()
        dp = array(file_data[0])
        # Run cal_error_metric() and create a json file containing all of the "pairwise" and "self" R & RMSE error measures
        Y = cem.cal_error_metric(dp, edges, start_scene, edge_array, file_directory, N_pairwise, N_self)
        output_file = open(file_directory + "output/" + "error_metric.json", 'w')
        json.dump([Y.tolist()], output_file)
        output_file.close()
        print ("cal_error_metric file written at" + (time.strftime("%H:%M:%S")))

# Gather parameters from the command line and run the function
parser = argparse.ArgumentParser(description="Run Forest Stand Height module")
parser.add_argument('scenes', type=int, help='number of scenes')
parser.add_argument('edges', type=int, help='number of edges')
parser.add_argument('start_scene', type=int, help='flag value of the start scene')
parser.add_argument('iterations', type=int, help='number of iterations')
parser.add_argument('linkfilename', type=str, help='filename of the linkfile')
parser.add_argument('flagfile', type=str, help='filename of the flagfile')
parser.add_argument('ref_file', type=str, help='filename of the reference data file')
parser.add_argument('maskfile', type=str, help='filename of the mask file')
parser.add_argument('file_directory', type=str, help='path of the file directory, make sure to finish with a slash to separate final directory and file')
parser.add_argument('filetypes', type=str, help='string of output file types. File types available: .gif, .json, .kml, .mat, .tif -- input without the ., such as \"kml\" instead of \".kml\"')
parser.add_argument('--Nd_pairwise', type=int, help='pixel-averaging parameter for edge fitting', nargs='?', default=20)
parser.add_argument('--Nd_self', type=int, help='pixel-averaging parameter for central scene fitting', nargs='?', default=10)
parser.add_argument('--N_pairwise', type=int, help='pixel-averaging parameter for edge error metrics', nargs='?', default=20)
parser.add_argument('--N_self', type=int, help='pixel-averaging parameter for central scene error metrics', nargs='?', default=10)
parser.add_argument('--bin_size', type=int, help='bin size for density calculation in sparse data cloud fitting', nargs='?', default=100)
parser.add_argument('--flag_sparse', type=int, help='optional flag for sparse data cloud filtering', choices=[0, 1], nargs='?', default=0)
parser.add_argument('--flag_diff', type=int, help='optional flag for exporting differential height maps', choices=[0, 1], nargs='?', default=0)
parser.add_argument('--flag_error', type=int, help='optional flag for exporting .json error metric files', choices=[0, 1], nargs='?', default=0)
parser.add_argument('--numLooks', type=int, help='number of looks in the correlation estimation', nargs='?', default=20)
parser.add_argument('--noiselevel', type=float, help='sensor thermal noise level (ALOS value hardcoded as default if no value provided)', nargs='?', default=0.0)
parser.add_argument('--flag_proc', type=int, help='optional flag for InSAR processor selection', choices=[0, 1], nargs='?', default=0)
parser.add_argument('--flag_grad', type=int, help='optional flag for correction of large-scale temporal change gradient', choices=[0, 1], nargs='?', default=0)

args = parser.parse_args()

print ("\n")
print (args)
print ("\n")

forest_stand_height(args.scenes, args.edges, args.start_scene, args.iterations, args.linkfilename, args.flagfile, args.ref_file, args.maskfile, args.file_directory, args.filetypes.strip().split(" "), args.Nd_pairwise, args.Nd_self, args.N_pairwise, args.N_self, args.bin_size, args.flag_sparse, args.flag_diff, args.flag_error, args.numLooks, args.noiselevel, args.flag_proc, args.flag_grad)
# Out:
#   File "/content/FSH/scripts/auto_tree_height_many.py", line 42
#     print "Invalid processor provided!!!"
#                                         ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Invalid processor provided!!!")?
